# %%
import pandas as pd  # Importa pandas con alias 'pd'
tabla = pd.read_csv('/Users/miguelpantigoso/Downloads/ventasTotales.csv', sep=';', skiprows=5)
# Lee el archivo CSV, usando ";" como separador y saltando las primeras 5 filas

tabla.head()
# Out:
#      Fecha          Vendedor Región           Artículo    Categoría  Unidades  \
# 0  1/01/16      Steve Ashton  Norte   Medias Femeninas   Vestimenta         6
# 1  1/01/16  Trevor Snodgrass  Oeste          Chocolate  Comestibles         8
# 2  1/01/16        Sarah Bond    Sur             Gorras   Vestimenta         3
# 3  1/01/16   Desmond Delaney    Sur  Sánguche de Queso  Comestibles         9
# 4  1/01/16   Desmond Delaney   Este          Chocolate  Comestibles        14
#
#   Ganancia
# 0    18,00
# 1     3,84
# 2     6,30
# 3    14,40
# 4     6,72

# %%
cat = tabla[(tabla.Vendedor == 'Sarah Bond') & ((tabla.Categoría == 'Vestimenta')| (tabla.Categoría == 'Comestibles'))]
cat
# Out:
#         Fecha    Vendedor Región           Artículo    Categoría  Unidades  \
# 2     1/01/16  Sarah Bond    Sur             Gorras   Vestimenta         3
# 9     1/01/16  Sarah Bond   Este          Caramelos  Comestibles        15
# 23    2/01/16  Sarah Bond  Norte            Bufanda   Vestimenta         4
# 48    4/01/16  Sarah Bond   Este             Shorts   Vestimenta         2
# 49    4/01/16  Sarah Bond  Norte             Shorts   Vestimenta        12
# 58    4/01/16  Sarah Bond   Este            Bufanda   Vestimenta        14
# 62    5/01/16  Sarah Bond  Norte            Cerveza  Comestibles         3
# 65    5/01/16  Sarah Bond  Norte                Pan  Comestibles         3
# 85    6/01/16  Sarah Bond  Norte             Gorras   Vestimenta         9
# 89    6/01/16  Sarah Bond    Sur            Cerveza  Comestibles        15
# 104   7/01/16  Sarah Bond   Este         Calcetines   Vestimenta        13
# ...

# %%
c = cat.groupby(['Artículo','Categoría','Región']).size()
c
# Out:
# Artículo           Categoría    Región
# Bufanda            Vestimenta   Este      2
#                                 Norte     1
#                                 Sur       2
# Calcetines         Vestimenta   Este      1
#                                 Norte     2
#                                 Oeste     2
#                                 Sur       1
# Caramelos          Comestibles  Este      1
#                                 Norte     2
# Cerveza            Comestibles  Este      2
#                                 Norte     2
#                                 Sur       1
# Chocolate          Comestibles  Este      1
#                                 Norte     2
#                                 Oeste     1
#                                 Sur       2
# Gorras             Vestimenta   Este      4
#                                 Norte     1
#                                 Sur       1
# Medias Femeninas   Vestimenta   Este      1
# ...

# %%
f = c.unstack('Región')
f
# Out:
# Región                         Este  Norte  Oeste  Sur
# Artículo          Categoría
# Bufanda           Vestimenta    2.0    1.0    NaN  2.0
# Calcetines        Vestimenta    1.0    2.0    2.0  1.0
# Caramelos         Comestibles   1.0    2.0    NaN  NaN
# Cerveza           Comestibles   2.0    2.0    NaN  1.0
# Chocolate         Comestibles   1.0    2.0    1.0  2.0
# Gorras            Vestimenta    4.0    1.0    NaN  1.0
# Medias Femeninas  Vestimenta    1.0    1.0    NaN  NaN
# Pan               Comestibles   NaN    2.0    NaN  4.0
# Pepinillo         Comestibles   1.0    1.0    1.0  1.0
# Sandalias         Vestimenta    NaN    NaN    1.0  1.0
# Shorts            Vestimenta    3.0    1.0    NaN  NaN
# Soda              Comestibles   NaN    NaN    1.0  2.0
# Sudadera          Vestimenta    1.0    NaN    NaN  1.0
# Sánguche de Queso Comestibles   2.0    1.0    NaN  NaN

# %%
#obentenemos un dataframe con un nuevo nivel de filas si quiero que sea mas alto uso stack
f.stack('Región')
# Out:
# Artículo           Categoría    Región
# Bufanda            Vestimenta   Este      2.0
#                                 Norte     1.0
#                                 Sur       2.0
# Calcetines         Vestimenta   Este      1.0
#                                 Norte     2.0
#                                 Oeste     2.0
#                                 Sur       1.0
# Caramelos          Comestibles  Este      1.0
#                                 Norte     2.0
# Cerveza            Comestibles  Este      2.0
#                                 Norte     2.0
#                                 Sur       1.0
# Chocolate          Comestibles  Este      1.0
#                                 Norte     2.0
#                                 Oeste     1.0
#                                 Sur       2.0
# Gorras             Vestimenta   Este      4.0
#                                 Norte     1.0
#                                 Sur       1.0
# ...

# %%
#con unstack 
f.unstack()
# Out:
# Región                   Este                  Norte                  Oeste  \
# Categoría         Comestibles Vestimenta Comestibles Vestimenta Comestibles
# Artículo
# Bufanda                   NaN        2.0         NaN        1.0         NaN
# Calcetines                NaN        1.0         NaN        2.0         NaN
# Caramelos                 1.0        NaN         2.0        NaN         NaN
# Cerveza                   2.0        NaN         2.0        NaN         NaN
# Chocolate                 1.0        NaN         2.0        NaN         1.0
# Gorras                    NaN        4.0         NaN        1.0         NaN
# Medias Femeninas          NaN        1.0         NaN        1.0         NaN
# Pan                       NaN        NaN         2.0        NaN         NaN
# Pepinillo                 1.0        NaN         1.0        NaN         1.0
# Sandalias                 NaN        NaN         NaN        NaN         NaN
# ...

# %%
f.unstack('Categoría', fill_value=0)
# Out:
# Región                   Este                  Norte                  Oeste  \
# Categoría         Comestibles Vestimenta Comestibles Vestimenta Comestibles
# Artículo
# Bufanda                   0.0        2.0         0.0        1.0         0.0
# Calcetines                0.0        1.0         0.0        2.0         0.0
# Caramelos                 1.0        0.0         2.0        0.0         NaN
# Cerveza                   2.0        0.0         2.0        0.0         NaN
# Chocolate                 1.0        0.0         2.0        0.0         1.0
# Gorras                    0.0        4.0         0.0        1.0         0.0
# Medias Femeninas          0.0        1.0         0.0        1.0         0.0
# Pan                       NaN        0.0         2.0        0.0         NaN
# Pepinillo                 1.0        0.0         1.0        0.0         1.0
# Sandalias                 0.0        NaN         0.0        NaN         0.0
# ...
